# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('StudentPerformance.csv')

# %%
print("Shape:", df.shape)
print(df.columns.tolist())
print(df.head())
df.describe()
df.info()
print("\nDtypes:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())

# %%
print("Average Performance Index:", df['Performance Index'].mean())
print("Max Performance Index:", df['Performance Index'].max())
print("Min Performance Index:", df['Performance Index'].min())

sns.histplot(data=df, x='Performance Index', bins=30, kde=True)
plt.show()

# %%
sns.scatterplot(data=df, x='Hours Studied',
                y='Performance Index',
                hue='Extracurricular Activities')
plt.title('Hours Studied vs Performance Index')
plt.show()

# %%
sns.scatterplot(data=df, x='Previous Scores',
                y='Performance Index',
                hue='Extracurricular Activities')
plt.title('Previous Scores vs Performance Index')
plt.show()

# %%
print(df.corr().round(2))

# %%
corr = df[['Hours Studied', 'Previous Scores',
           'Sleep Hours',
           'Sample Question Papers Practiced',
           'Performance Index']].corr()

sns.heatmap(corr, annot=True,
            cmap='coolwarm',
            fmt='.2f',
            linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
print(df.groupby('Extracurricular Activities')['Performance Index'].mean())

sns.barplot(data=df,
            x='Extracurricular Activities',
            y='Performance Index')
plt.title('Extracurricular Activities VS Performance Index')
plt.show()

# %%
print(df.groupby('Sleep Hours')['Performance Index'].mean())

sns.barplot(data=df,
            x='Sleep Hours',
            y='Performance Index')
plt.title('Sleep Hours vs Performance Index')
plt.show()

# %%
sns.pairplot(df[['Hours Studied', 'Previous Scores',
                 'Sleep Hours',
                 'Sample Question Papers Practiced',
                 'Performance Index',
                 'Extracurricular Activities']],
             hue='Extracurricular Activities',
             palette='Set2',
             diag_kind='kde',
             plot_kws={'alpha':0.5})
plt.suptitle('Pairplot — StudentPerformance Analysis',
             y=1.02, fontsize=14, fontweight='bold')
plt.show()
